# %% [markdown]
# Research Question # 1 : Is there an association between the amount of time someone's been in a relationship and education
#
# > Indented block

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1: ![Screenshot 2023-04-27 11.59.36 AM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['Relationship_Years'] = df['H4RD2Y']
df['Relationship_Years']= pd.to_numeric(df['Relationship_Years'],errors= 'coerce')
df['Relationship_Years']= df['Relationship_Years'].loc[df['Relationship_Years'] != ' ']
df['Relationship_Years']= df['Relationship_Years'].loc[df['Relationship_Years'] < 96]
df['Relationship_Years'].value_counts()
# Out:
# 0.0     946
# 1.0     537
# 2.0     438
# 3.0     406
# 4.0     343
# 5.0     341
# 7.0     322
# 6.0     305
# 8.0     296
# 10.0    255
# 9.0     224
# 11.0    138
# 12.0    127
# 13.0     78
# 14.0     43
# 15.0     31
# 16.0     11
# 17.0      8
# 18.0      1
# 19.0      1
# Name: Relationship_Years, dtype: int64

# %%
df['Relationship_Months']= df['H4RD2M']
df['Relationship_Months']= pd.to_numeric(df['Relationship_Months'],errors= 'coerce')
df['Relationship_Months']= df['Relationship_Months'].loc[df['Relationship_Months'] < 96]
df['Relationship_Months']= df['Relationship_Months'].loc[df['Relationship_Months'] != ' ']
df['Relationship_Months'].value_counts()
# Out:
# 0.0     1318
# 6.0      508
# 2.0      414
# 1.0      386
# 3.0      374
# 4.0      324
# 8.0      274
# 5.0      268
# 9.0      261
# 7.0      250
# 10.0     229
# 11.0     188
# Name: Relationship_Months, dtype: int64

# %%
df['Relationship_Time'] = df['Relationship_Years'] *12+ df['Relationship_Months']

# %%
#Graphs and tables or statistics

# %%
sns.histplot(x='Relationship_Time', data=df)
# Out:
# <Axes: xlabel='Relationship_Time', ylabel='Count'>

# %%
sns.boxplot(x= 'Relationship_Time', data=df)
# Out:
# <Axes: xlabel='Relationship_Time'>

# %% [markdown]
# Codebook 2:![Screenshot 2023-04-27 12.00.33 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['H4ED3A'].value_counts()
# Out:
# 97    1416
#       1390
# 4     1187
# 1     1166
# 2      471
# 3      470
# 6      280
# 8       75
# 5       34
# 7       14
# 98       1
# Name: H4ED3A, dtype: int64

# %%
df['educational_success'] = df['H4ED3A']

# %%
df['educational_success'] = df['educational_success'].loc[ df['educational_success'] !=' ']
df['educational_success'] = df['educational_success'].loc[ df['educational_success'] !='96']
df['educational_success'] = df['educational_success'].loc[ df['educational_success'] !='97']
df['educational_success'] = df['educational_success'].loc[ df['educational_success'] !='98']
df['educational_success'].value_counts()
# Out:
# 4    1187
# 1    1166
# 2     471
# 3     470
# 6     280
# 8      75
# 5      34
# 7      14
# Name: educational_success, dtype: int64

# %%
df['educational_success'].replace(['1','2','3','4','5','6','7','8'] , ['has not recieved degree', 'certificate/degree from vocational program', 'associates degree', 'bachelors degree','certificate from post baccalauerate program','masters degree','PhD','doctorates'], inplace = True)
df['educational_success'].value_counts()
# Out:
# bachelors degree                               1187
# has not recieved degree                        1166
# certificate/degree from vocational program      471
# associates degree                               470
# masters degree                                  280
# doctorates                                       75
# certificate from post baccalauerate program      34
# PhD                                              14
# Name: educational_success, dtype: int64

# %%
#Graphs and tables or statistics

# %%
df['educational_success'].value_counts().plot(kind ='pie')
# Out:
# <Axes: ylabel='educational_success'>

# %%
df['educational_success'].value_counts(normalize = True).plot(kind ='bar')
# Out:
# <Axes: >
